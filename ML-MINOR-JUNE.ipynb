# %% [markdown]
# ## ML-MINOR-JUNE

# %% [markdown]
# AIM:
# 1. Import the dataset.
# 2. Data quality check:
# a. Check if null values are present. If there are, drop those rows.
# 3. Exploratory Data Analysis:
# a. Univariate Analysis:
# i. Draw a minimum of 5 histograms .
# ii. Draw boxplots for each numerical columns.
# b. Bivariate analysis:
# i. Draw a minimum of 5 scatter plots
#
# 4. Modelling:
# a. Split the dataset using “train-test-split” function.
# b. Apply KNN classification on “quality” column of the dataset. Select the
# appropriate features
# c. Apply logistic Regression on “quality” column of the dataset. Select the
# appropriate features
# d. Predict on the test set.
# e. Find out the accuracy.

# %% [markdown]
# ### 1 . Import the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("winequality-red.csv")

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %% [markdown]
# ### 2. Null value check

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### 3. Exploratory Data Analysis

# %% [markdown]
# #### Univariate Analysis

# %% [markdown]
# #### i] 5 Histograms

# %%
import math

# %%
arr = np.arange(4,17)
bins = data['fixed acidity'].count()
bins = math.sqrt(int(bins))
plt.hist(data['fixed acidity'],bins=round(bins))
plt.xlabel('Fixed Acidity')
plt.ylabel('Count')
plt.xticks(arr)
plt.title('Fixed Acidity Level in Wine')
plt.show()

# %%
arr = np.arange(2.7,4.1,0.1)
bins = data['pH'].count()
bins = math.sqrt(int(bins))
plt.hist(data['pH'],bins=round(bins))
plt.xlabel('pH Values')
plt.ylabel('Count')
plt.xticks(arr)
plt.title('pH Level in Wine')
plt.show()

# %%
plt.hist(data['citric acid'],bins=15)
plt.xlabel('Citric Acid')
plt.ylabel('Count')
plt.title('Citric Acid Level in Wine')
plt.show()

# %%
plt.hist(data['alcohol'],bins=25)
plt.xlabel('Alcohol Quantity')
plt.ylabel('Count')
plt.title('Alcohol Level in Wine')
plt.show()

# %%
bins = data['density'].count()
bins = math.sqrt(int(bins))
plt.hist(data['density'],bins=round(bins))
plt.xlabel('Density')
plt.ylabel('Count')
plt.title('Desity variation in Wine')
plt.show()

# %% [markdown]
# #### ii] Boxplot of all numerical columns

# %%
col = data.columns.tolist()
col
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
for i in col:
    if i != 'quality':
        plt.title('Box Plotting of numerical values')
        sns.boxplot(x='quality', y= i, data=data)
        plt.show()

# %% [markdown]
# #### Bivariate analysis

# %% [markdown]
# #### 5 scatter plots

# %%
plt.scatter(x=data['fixed acidity'], y=data['pH'], edgecolors='black', alpha=0.75, c='yellow')
plt.xlabel('Fixed Acidity')
plt.ylabel('pH Level')
plt.title('Scatter plot - Fixed Acidity Vs pH Level')
plt.show()

# %%
plt.scatter(x=data['residual sugar'], y=data['density'], edgecolors='black', alpha=0.75, c='blue')
plt.xlabel('Residual sugar')
plt.ylabel('Density')
plt.title('Scatter plot - Residual sugar Vs Density')
plt.show()

# %%
plt.scatter(x=data['free sulfur dioxide'], y=data['total sulfur dioxide'], edgecolors='black', alpha=0.75, c='orange')
plt.xlabel('Free sulfur dioxide')
plt.ylabel('Total sulfur dioxide')
plt.title('Scatter plot - Free sulfur dioxide Vs Total sulfur dioxide')
plt.show()

# %%
plt.scatter(x=data['chlorides'], y=data['sulphates'], edgecolors='black', alpha=0.75, c='green')
plt.xlabel('Chlorides')
plt.ylabel('Sulphates')
plt.title('Scatter plot - Chlorides Vs Sulphates')
plt.show()

# %%
plt.scatter(x=data['alcohol'], y=data['quality'], edgecolors='black', alpha=0.5, c='maroon')
plt.xlabel('Alcohol')
plt.ylabel('Quality')
plt.title('Scatter plot - Alcohol Vs Quality')
plt.show()

# %% [markdown]
# ### Modelling

# %% [markdown]
# #### a. Split the dataset using “train-test-split” function.

# %%
from sklearn.model_selection import train_test_split
x = data.iloc[:,:-1].values
y = data.iloc[:,-1].values
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# #### b. Apply KNN classification on “quality” column of the dataset. Select the appropriate features

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
pred = knn.predict(x_test)
#print(np.concatenate((pred.reshape(len(pred),1), y_test.reshape(len(y_test),1)), 1))
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test,pred)

# %%
print("Accuracy using KNN classification is", np.round(acc*100,2) ,"%")
# Out:
# Accuracy using KNN classification is 60.62 %

# %% [markdown]
# #### c. Apply logistic Regression on “quality” column of the dataset. Select the appropriate features

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=0)
classifier.fit(x_train,y_train)
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=0, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# #### d. Predict on the test set.

# %%
y_pred = classifier.predict(x_test)
#print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)), 1))

# %% [markdown]
# #### e. Find out the accuracy.

# %%
from sklearn.metrics import accuracy_score
result = accuracy_score(y_test,y_pred)
print("Thus the accuracy score is",np.round(result*100,2),"%")
# Out:
# Thus the accuracy score is 62.81 %
